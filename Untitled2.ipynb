# %%
import pandas as pd

# %%
df =pd.read_csv('/Jio - Jio Prepaid Planes.csv')

# %%
df.head()
# Out:
#    Days  Price  Price/Day  For 365 Days  Profit per customer  \
# 0    28    209   7.464286   2724.464286             5.214286
# 1    24    179   7.458333   2722.291667             3.041667
# 2    20    149   7.450000   2719.250000             0.000000
# 3   336   2545   7.574405   2764.657738             0.000000
# 4    84    666   7.928571   2893.928571           129.270833
#
#    From 400 Million users  Data_per_day
# 0             2085.714286           1.0
# 1             1216.666667           1.0
# 2                0.000000           1.0
# 3                0.000000           1.5
# 4            51708.333330           1.5

# %%
df.head(15)
# Out:
#     Days  Price  Price/Day  For 365 Days  Profit per customer  \
# 0     28    209   7.464286   2724.464286             5.214286
# 1     24    179   7.458333   2722.291667             3.041667
# 2     20    149   7.450000   2719.250000             0.000000
# 3    336   2545   7.574405   2764.657738             0.000000
# 4     84    666   7.928571   2893.928571           129.270833
# 5     56    479   8.553571   3122.053571           357.395833
# 6     30    259   8.633333   3151.166667           386.508929
# 7     28    239   8.535714   3115.535714           350.877976
# 8     23    199   8.652174   3158.043478           393.385740
# 9     14    119   8.500000   3102.500000           337.842262
# 10   365   2879   7.887671   2879.000000             0.000000
# 11    56    533   9.517857   3474.017857           595.017857
# 12    28    299  10.678571   3897.678571          1018.678571
# 13    23    249  10.826087   3951.521739          1072.521739
# ...

# %%
df.tail()
# Out:
#     Days  Price  Price/Day  For 365 Days  Profit per customer  \
# 11    56    533   9.517857   3474.017857           595.017857
# 12    28    299  10.678571   3897.678571          1018.678571
# 13    23    249  10.826087   3951.521739          1072.521739
# 14    84   1199  14.273810   5209.940476             0.000000
# 15    28    419  14.964286   5461.964286           252.023809
#
#     From 400 Million users  Data_per_day
# 11             238007.1429           2.0
# 12             407471.4286           2.0
# 13             429008.6957           2.0
# 14                  0.0000           3.0
# 15             100809.5238           3.0

# %%
df.describe()
# Out:
#              Days        Price  Price/Day  For 365 Days  Profit per customer  \
# count   16.000000    16.000000  16.000000     16.000000            16.000000
# mean    76.687500   663.812500   9.306167   3396.750914           306.361219
# std    109.140716   845.097645   2.320658    847.040309           345.420462
# min     14.000000   119.000000   7.450000   2719.250000             0.000000
# 25%     23.750000   206.500000   7.809355   2850.414434             2.281250
# 50%     28.000000   279.000000   8.544643   3118.794643           294.933036
# 75%     63.000000   566.250000   9.808036   3579.933035           388.228132
# max    365.000000  2879.000000  14.964286   5461.964286          1072.521739
#
#        From 400 Million users  Data_per_day
# count               16.000000     16.000000
# mean            122544.487586      1.718750
# std             138168.184724      0.604669
# min                  0.000000      1.000000
# 25%                912.500000      1.500000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Days                    16 non-null     int64
#  1   Price                   16 non-null     int64
#  2   Price/Day               16 non-null     float64
#  3   For 365 Days            16 non-null     float64
#  4   Profit per customer     16 non-null     float64
#  5   From 400 Million users  16 non-null     float64
#  6   Data_per_day            16 non-null     float64
# dtypes: float64(5), int64(2)
# memory usage: 1.0 KB

# %%
df.columns
# Out:
# Index(['Days', 'Price', 'Price/Day', 'For 365 Days', 'Profit per customer',
#        'From 400 Million users', 'Data_per_day'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Days',
#  'Price',
#  'Price/Day',
#  'For 365 Days',
#  'Profit per customer',
#  'From 400 Million users',
#  'Data_per_day']

# %%
df.shape
# Out:
# (16, 7)

# %%
print(df.shape[0])
# Out:
# 16

# %%
print(df.shape[1])
# Out:
# 7

# %%
df.dtypes
# Out:
# Days                        int64
# Price                       int64
# Price/Day                 float64
# For 365 Days              float64
# Profit per customer       float64
# From 400 Million users    float64
# Data_per_day              float64
# dtype: object

# %%
df.isnull()
# Out:
#      Days  Price  Price/Day  For 365 Days  Profit per customer  \
# 0   False  False      False         False                False
# 1   False  False      False         False                False
# 2   False  False      False         False                False
# 3   False  False      False         False                False
# 4   False  False      False         False                False
# 5   False  False      False         False                False
# 6   False  False      False         False                False
# 7   False  False      False         False                False
# 8   False  False      False         False                False
# 9   False  False      False         False                False
# 10  False  False      False         False                False
# 11  False  False      False         False                False
# 12  False  False      False         False                False
# 13  False  False      False         False                False
# ...

# %%
df.isnull().sum()
# Out:
# Days                      0
# Price                     0
# Price/Day                 0
# For 365 Days              0
# Profit per customer       0
# From 400 Million users    0
# Data_per_day              0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Days                      False
# Price                     False
# Price/Day                 False
# For 365 Days              False
# Profit per customer       False
# From 400 Million users    False
# Data_per_day              False
# dtype: bool

# %%
df.keys()
# Out:
# Index(['Days', 'Price', 'Price/Day', 'For 365 Days', 'Profit per customer',
#        'From 400 Million users', 'Data_per_day'],
#       dtype='object')

# %%
df.values
# Out:
# array([[2.80000000e+01, 2.09000000e+02, 7.46428571e+00, 2.72446429e+03,
#         5.21428571e+00, 2.08571429e+03, 1.00000000e+00],
#        [2.40000000e+01, 1.79000000e+02, 7.45833333e+00, 2.72229167e+03,
#         3.04166667e+00, 1.21666667e+03, 1.00000000e+00],
#        [2.00000000e+01, 1.49000000e+02, 7.45000000e+00, 2.71925000e+03,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [3.36000000e+02, 2.54500000e+03, 7.57440476e+00, 2.76465774e+03,
#         0.00000000e+00, 0.00000000e+00, 1.50000000e+00],
#        [8.40000000e+01, 6.66000000e+02, 7.92857143e+00, 2.89392857e+03,
#         1.29270833e+02, 5.17083333e+04, 1.50000000e+00],
#        [5.60000000e+01, 4.79000000e+02, 8.55357143e+00, 3.12205357e+03,
#         3.57395833e+02, 1.42958333e+05, 1.50000000e+00],
#        [3.00000000e+01, 2.59000000e+02, 8.63333333e+00, 3.15116667e+03,
#         3.86508929e+02, 1.54603571e+05, 1.50000000e+00],
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df.rank()
# Out:
#     Days  Price  Price/Day  For 365 Days  Profit per customer  \
# 0    7.5    5.0        3.0           3.0                  6.0
# 1    5.0    3.0        2.0           2.0                  5.0
# 2    2.0    2.0        1.0           1.0                  2.5
# 3   15.0   15.0        4.0           4.0                  2.5
# 4   13.5   13.0        6.0           6.0                  7.0
# 5   11.5   11.0        9.0           9.0                 11.0
# 6   10.0    8.0       10.0          10.0                 12.0
# 7    7.5    6.0        8.0           8.0                 10.0
# 8    3.5    4.0       11.0          11.0                 13.0
# 9    1.0    1.0        7.0           7.0                  9.0
# 10  16.0   16.0        5.0           5.0                  2.5
# 11  11.5   12.0       12.0          12.0                 14.0
# 12   7.5    9.0       13.0          13.0                 15.0
# 13   3.5    7.0       14.0          14.0                 16.0
# ...

# %%
df['Data_per_day']
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.5
# 4     1.5
# 5     1.5
# 6     1.5
# 7     1.5
# 8     1.5
# 9     1.5
# 10    2.0
# 11    2.0
# 12    2.0
# 13    2.0
# 14    3.0
# 15    3.0
# Name: Data_per_day, dtype: float64

# %%
df[['Data_per_day','Profit per customer']].head(10)
# Out:
#    Data_per_day  Profit per customer
# 0           1.0             5.214286
# 1           1.0             3.041667
# 2           1.0             0.000000
# 3           1.5             0.000000
# 4           1.5           129.270833
# 5           1.5           357.395833
# 6           1.5           386.508929
# 7           1.5           350.877976
# 8           1.5           393.385740
# 9           1.5           337.842262
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_44['Data_per_day'].plot(kind='hist', bins=20, title='Data_per_day')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_45['Profit per customer'].plot(kind='hist', bins=20, title='Profit per customer')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df[df.index==7]
# Out:
#    Days  Price  Price/Day  For 365 Days  Profit per customer  \
# 7    28    239   8.535714   3115.535714           350.877976
#
#    From 400 Million users  Data_per_day
# 7             140351.1905           1.5

# %%
df[df.index.isin(range(3,15))]
# Out:
#     Days  Price  Price/Day  For 365 Days  Profit per customer  \
# 3    336   2545   7.574405   2764.657738             0.000000
# 4     84    666   7.928571   2893.928571           129.270833
# 5     56    479   8.553571   3122.053571           357.395833
# 6     30    259   8.633333   3151.166667           386.508929
# 7     28    239   8.535714   3115.535714           350.877976
# 8     23    199   8.652174   3158.043478           393.385740
# 9     14    119   8.500000   3102.500000           337.842262
# 10   365   2879   7.887671   2879.000000             0.000000
# 11    56    533   9.517857   3474.017857           595.017857
# 12    28    299  10.678571   3897.678571          1018.678571
# 13    23    249  10.826087   3951.521739          1072.521739
# 14    84   1199  14.273810   5209.940476             0.000000
#
#     From 400 Million users  Data_per_day
# 3                  0.00000           1.5
# 4              51708.33333           1.5
# ...

# %%
df.loc[10]
# Out:
# Days                       365.000000
# Price                     2879.000000
# Price/Day                    7.887671
# For 365 Days              2879.000000
# Profit per customer          0.000000
# From 400 Million users       0.000000
# Data_per_day                 2.000000
# Name: 10, dtype: float64

# %%
df.to_numpy()
# Out:
# array([[2.80000000e+01, 2.09000000e+02, 7.46428571e+00, 2.72446429e+03,
#         5.21428571e+00, 2.08571429e+03, 1.00000000e+00],
#        [2.40000000e+01, 1.79000000e+02, 7.45833333e+00, 2.72229167e+03,
#         3.04166667e+00, 1.21666667e+03, 1.00000000e+00],
#        [2.00000000e+01, 1.49000000e+02, 7.45000000e+00, 2.71925000e+03,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [3.36000000e+02, 2.54500000e+03, 7.57440476e+00, 2.76465774e+03,
#         0.00000000e+00, 0.00000000e+00, 1.50000000e+00],
#        [8.40000000e+01, 6.66000000e+02, 7.92857143e+00, 2.89392857e+03,
#         1.29270833e+02, 5.17083333e+04, 1.50000000e+00],
#        [5.60000000e+01, 4.79000000e+02, 8.55357143e+00, 3.12205357e+03,
#         3.57395833e+02, 1.42958333e+05, 1.50000000e+00],
#        [3.00000000e+01, 2.59000000e+02, 8.63333333e+00, 3.15116667e+03,
#         3.86508929e+02, 1.54603571e+05, 1.50000000e+00],
# ...
